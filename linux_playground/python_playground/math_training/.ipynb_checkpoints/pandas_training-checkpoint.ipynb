# %%
import time

# %%
from linux_playground.utils.path_utils.specific_paths import relative_path
survey_results_path: str = "survey_results_public.csv"

# %%
survey_results_path
# Out:
# 'stack-overflow-developer-survey-2025/survey_results_public.csv'

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(survey_results_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv(survey_results_path)
#
# File ~/git_repos/linux_playground/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...
